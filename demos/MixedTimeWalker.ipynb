# %% [markdown]
# # Animal Movement Analysis with MixedTimeWalker
#
# ## 1. Setup & Imports
#
# This notebook demonstrates the use of the `MixedTimeWalker` class to generate animal movement paths using Movebank data with time-dependent environmental factors. The implementation supports weather integration and terrain analysis for realistic movement simulation.
#
# ### Overview
#
# In this initial setup phase, we will:
#
# - **Load Movebank study data** from CSV files in the resources directory
# - **Preprocess environmental data** including terrain and weather conditions
# - **Configure time-dependent parameters** for movement analysis
# - **Set up weather grid integration** for realistic environmental simulation
#
# ### Study Configuration
#
# You can work with:
#
# - **Pre-loaded studies** from the resources folder
# - **Custom studies** by providing the path to a folder containing your `animal_data.csv` file
#
# ### Output Management
#
# The analysis process generates and organizes:
#
# - **Fetched landcover data** for terrain analysis
# - **Gridded weather data** for environmental conditions
# - **Serialized movement data** for efficient processing
# - **JSON trajectory files** with time-stamped paths
# - **Interactive Leaflet HTML maps** displaying generated time-dependent walks between actual Movebank observations
#
# > **Note:**
# > **Weather API Rate Limits**: This implementation uses the free Open-Meteo API which has rate limits. If weather data fetching fails, please wait approximately 1 minute (the minute rate limit is typically exceeded) and restart the function. The system will resume from the last failed weather record, and the process should complete successfully within 1-3 attempts.
#
# ### Key Features
#
# - **Time-aware movement simulation** with environmental factors
# - **Automatic parameter optimization** based on segment characteristics
# - **Per-animal terrain and weather processing** for accurate simulations
# - **Flexible duration configuration** for movement analysis
# - **Comprehensive visualization** with interactive maps

# %%
import webbrowser

from random_walk_package.bindings import create_mixed_kernel_parameters, LIGHT
from random_walk_package.core.MixedTimeWalker import MixedTimeWalker

studies = ["elephant_study/", "baboon_SA_study/", "leap_of_the_cat/", "Boars_Austria/", "Cranes Kazakhstan/"]
study = studies[2]

kernel_mapping = create_mixed_kernel_parameters(animal_type=LIGHT, base_step_size=5)

walker = MixedTimeWalker(
    T=50,
    resolution=100,
    duration_in_days=3,
    study_folder=studies[2]
)
walk_path = walker.generate_walk_from_movebank(serialized=False)

webbrowser.open(f'file://{walk_path}')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/PycharmProjects/random-walks-python/random_walk_package/core/AnimalMovement.py:106, in _fetch_hourly_data_for_period_at_point(lat, lon, start_date_str, end_date_str, fetch_hourly)
#     105 response = requests.get("https://archive-api.open-meteo.com/v1/archive", params=params)
# --> 106 response.raise_for_status()
#     107 data = response.json()
#
# File ~/PycharmProjects/random-walks-python/.venv/lib/python3.13/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 429 Client Error: Too Many Requests for url: https://archive-api.open-meteo.com/v1/archive?latitude=-22.53548920322343&longitude=-52.324983456135875&start_date=2000-01-21&end_date=2001-02-24&daily=weather_code%2Ctemperature_2m_mean%2Crelative_humidity_2m_mean%2Cprecipitation_sum%2Csnowfall_sum%2Cwind_speed_10m_max%2Cwind_direction_10m_dominant%2Ccloud_cover_mean&timezone=UTC
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 11
#       7 study = studies[2]
#       9 kernel_mapping = create_mixed_kernel_parameters(animal_type=LIGHT, base_step_size=5)
# ---> 11 walker = MixedTimeWalker(
#      12     T=50,
#      13     resolution=100,
#      14     duration_in_days=3,
#      15     study_folder=studies[2]
#      16 )
#      17 walk_path = walker.generate_walk_from_movebank(serialized=False)
#      19 webbrowser.open(f'file://{walk_path}')
#
# File ~/PycharmProjects/random-walks-python/random_walk_package/core/MixedTimeWalker.py:52, in MixedTimeWalker.__init__(self, resolution, T, grid_points_per_edge, duration_in_days, mapping, study_folder)
#      50 self.terrain_path = self.study_folder
#      51 self.duration_in_days = duration_in_days
# ---> 52 self._preprocess()
#
# File ~/PycharmProjects/random-walks-python/random_walk_package/core/MixedTimeWalker.py:58, in MixedTimeWalker._preprocess(self)
#      55 self.movebank_processor = AnimalMovementProcessor(self.movebank_study)
#      56 self.terrain_path = self.movebank_processor.create_landcover_data_txt(self.resolution,
#      57                                                                       out_directory=self.study_folder)
# ---> 58 self.weather_data_dict = self.movebank_processor.fetch_gridded_weather_data(self.csv_path,
#      59                                                                             grid_points_per_edge=self.grid_points_per_edge)
#
# File ~/PycharmProjects/random-walks-python/random_walk_package/core/AnimalMovement.py:504, in AnimalMovementProcessor.fetch_gridded_weather_data(self, output_folder, grid_points_per_edge)
#     501 for i, (lat, lon) in enumerate(grid_points_to_query):
#     502     print(
#     503         f"[{animal_id}] Fetching weather for grid point {i + 1}/{total_points_to_fetch} (Lat: {lat:.4f}, Lon: {lon:.4f})")
# --> 504     point_weather_data_list = _fetch_hourly_data_for_period_at_point(
#     505         lat, lon, start_date.strftime("%Y-%m-%d"), end_date.strftime("%Y-%m-%d"), fetch_hourly
#     506     )
#     507     # Save per-grid-point CSV
#     508     y_idx = i // grid_points_per_edge
#
# File ~/PycharmProjects/random-walks-python/random_walk_package/core/AnimalMovement.py:180, in _fetch_hourly_data_for_period_at_point(lat, lon, start_date_str, end_date_str, fetch_hourly)
#     178         print("Bad request, not retrying for this point.")
#     179         break
# --> 180     time.sleep(2 ** attempt)
#     181 except requests.exceptions.RequestException as e:
#     182     print(
#     183         f"Attempt {attempt + 1} (RequestException) for {lat},{lon} ({start_date_str}-{end_date_str}): {str(e)}")
#
# KeyboardInterrupt:
